# %% [markdown]
# **OpenAI Key**

# %%
import os
from getpass import getpass
from semantic_router.encoders import OpenAIEncoder

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY") or getpass("OpenAI API key: ")
# Out:
# OpenAI API key:  ········

# %%
from langchain.prompts import PromptTemplate
from langchain.chat_models import ChatOpenAI
from langchain.chains import LLMChain
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.schema import SystemMessage, HumanMessage
from tqdm.auto import tqdm

# %% [markdown]
# **SAMPLE DATA**

# %%
import pandas as pd

# Example data
data = pd.DataFrame({
    "id": range(1, 51),
    "sender": ["user" if i % 2 == 0 else "agent" for i in range(1, 51)],
    "timestamp": pd.date_range(start="2023-01-01", periods=50, freq="min"),
    "conversation_id": [1] * 50,  # single conversation ID
    "message": ["This is message " + str(i) for i in range(1, 51)]
})

# %%
conversation_durations = data.groupby("conversation_id").agg(
    start_time=("timestamp", "min"),
    end_time=("timestamp", "max")
)

# %%
print(conversation_durations)
# Out:
#                 start_time            end_time
# conversation_id
# 1               2023-01-01 2023-01-01 00:49:00

# %%
data
# Out:
#     id sender           timestamp  conversation_id             message
# 0    1  agent 2023-01-01 00:00:00                1   This is message 1
# 1    2   user 2023-01-01 00:01:00                1   This is message 2
# 2    3  agent 2023-01-01 00:02:00                1   This is message 3
# 3    4   user 2023-01-01 00:03:00                1   This is message 4
# 4    5  agent 2023-01-01 00:04:00                1   This is message 5
# 5    6   user 2023-01-01 00:05:00                1   This is message 6
# 6    7  agent 2023-01-01 00:06:00                1   This is message 7
# 7    8   user 2023-01-01 00:07:00                1   This is message 8
# 8    9  agent 2023-01-01 00:08:00                1   This is message 9
# 9   10   user 2023-01-01 00:09:00                1  This is message 10
# 10  11  agent 2023-01-01 00:10:00                1  This is message 11
# 11  12   user 2023-01-01 00:11:00                1  This is message 12
# 12  13  agent 2023-01-01 00:12:00                1  This is message 13
# 13  14   user 2023-01-01 00:13:00                1  This is message 14
# 14  15  agent 2023-01-01 00:14:00                1  This is message 15
# 15  16   user 2023-01-01 00:15:00                1  This is message 16
# 16  17  agent 2023-01-01 00:16:00                1  This is message 17
# 17  18   user 2023-01-01 00:17:00                1  This is message 18
# 18  19  agent 2023-01-01 00:18:00                1  This is message 19
# 19  20   user 2023-01-01 00:19:00                1  This is message 20
# 20  21  agent 2023-01-01 00:20:00                1  This is message 21
# 21  22   user 2023-01-01 00:21:00                1  This is message 22
# 22  23  agent 2023-01-01 00:22:00                1  This is message 23
# 23  24   user 2023-01-01 00:23:00                1  This is message 24
# 24  25  agent 2023-01-01 00:24:00                1  This is message 25
# 25  26   user 2023-01-01 00:25:00                1  This is message 26
# 26  27  agent 2023-01-01 00:26:00                1  This is message 27
# 27  28   user 2023-01-01 00:27:00                1  This is message 28
# 28  29  agent 2023-01-01 00:28:00                1  This is message 29
# 29  30   user 2023-01-01 00:29:00                1  This is message 30
# 30  31  agent 2023-01-01 00:30:00                1  This is message 31
# 31  32   user 2023-01-01 00:31:00                1  This is message 32
# 32  33  agent 2023-01-01 00:32:00                1  This is message 33
# 33  34   user 2023-01-01 00:33:00                1  This is message 34
# 34  35  agent 2023-01-01 00:34:00                1  This is message 35
# 35  36   user 2023-01-01 00:35:00                1  This is message 36
# 36  37  agent 2023-01-01 00:36:00                1  This is message 37
# 37  38   user 2023-01-01 00:37:00                1  This is message 38
# 38  39  agent 2023-01-01 00:38:00                1  This is message 39
# 39  40   user 2023-01-01 00:39:00                1  This is message 40
# 40  41  agent 2023-01-01 00:40:00                1  This is message 41
# 41  42   user 2023-01-01 00:41:00                1  This is message 42
# 42  43  agent 2023-01-01 00:42:00                1  This is message 43
# 43  44   user 2023-01-01 00:43:00                1  This is message 44
# 44  45  agent 2023-01-01 00:44:00                1  This is message 45
# 45  46   user 2023-01-01 00:45:00                1  This is message 46
# 46  47  agent 2023-01-01 00:46:00                1  This is message 47
# 47  48   user 2023-01-01 00:47:00                1  This is message 48
# 48  49  agent 2023-01-01 00:48:00                1  This is message 49
# 49  50   user 2023-01-01 00:49:00                1  This is message 50

# %% [markdown]
# **Storing messages in vector DB**

# %%
# Initialize embeddings and Chroma vector store
embeddings = OpenAIEmbeddings()
vectorstore = Chroma(embedding_function=embeddings)

# Set batch size
batch_size = 512

# Process and add chat messages in batches
for i in tqdm(range(0, len(data), batch_size)):
    i_end = min(len(data), i + batch_size)
    batch = data[i:i_end].to_dict(orient="records")

    # Prepare metadata and message content for Chroma
    metadata = [{
        "sender": r["sender"],
        "timestamp": str(r["timestamp"]),
        "conversation_id": str(r["conversation_id"])
    } for r in batch]

    # Generate unique IDs for each chat message
    ids = [str(r["id"]) for r in batch]

    # Get the chat messages to embed
    messages = [r["message"] for r in batch]

    # Embed messages
    embeds = embeddings.embed_documents(messages)

    # Add messages to Chroma with embeddings, IDs, and metadata
    vectorstore.add_texts(
        texts=messages,
        metadatas=metadata,
        ids=ids
    )
# Out:
# /tmp/ipykernel_3781/2634740084.py:2: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings()
# /tmp/ipykernel_3781/2634740084.py:3: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vectorstore = Chroma(embedding_function=embeddings)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
metadata
# Out:
# [{'sender': 'agent',
#   'timestamp': '2023-01-01 00:00:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:01:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:02:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:03:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:04:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:05:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:06:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:07:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:08:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:09:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:10:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:11:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:12:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:13:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:14:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:15:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:16:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:17:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:18:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:19:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:20:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:21:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:22:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:23:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:24:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:25:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:26:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:27:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:28:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:29:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:30:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:31:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:32:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:33:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:34:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:35:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:36:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:37:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:38:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:39:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:40:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:41:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:42:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:43:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:44:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:45:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:46:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:47:00',
#   'conversation_id': '1'},
#  {'sender': 'agent',
#   'timestamp': '2023-01-01 00:48:00',
#   'conversation_id': '1'},
#  {'sender': 'user',
#   'timestamp': '2023-01-01 00:49:00',
#   'conversation_id': '1'}]

# %%
len(messages)
# Out:
# 50

# %% [markdown]
# **Pulling messages from vector DB and running a summary on it (with test variable)**

# %%
# --- Retrieve Messages and Summarize ---

# Initialize the language model for chat-based models
llm = ChatOpenAI(model="gpt-3.5-turbo")

# Retrieve the relevant messages from Chroma
query_message = " "  # Example query
results = vectorstore.similarity_search(query=query_message, k=len(messages))  # Adjust k as needed

# Format the retrieved data into the conversation structure
#conversation = [
#    {
#        "sender": result.metadata.get("sender", "unknown"),
#        "timestamp": result.metadata.get("timestamp", "unknown"),
#        "message": result.page_content
#    }
#    for result in results
#]

conversation = [
    {"sender": "user", 'timestamp': '2023-01-01 00:13:00', "message": "Hi, What do you think about my drawing?"},
    {"sender": "agent", 'timestamp': '2023-01-01 00:13:15', "message": "Great! I might need more blue for the ocean water."},
    {"sender": "user", 'timestamp': '2023-01-01 00:13:20', "message": "Ok! Anything else that I need to add?"},
    {"sender": "agent", 'timestamp': '2023-01-01 00:13:25', "message": "To make it stand out, color the trees with different shades of green!"}
    # Add more messages as needed...
]


# Combine messages into a single conversation string for summarization
conversation_text = "\n".join([f"{msg['sender']} ({msg['timestamp']}): {msg['message']}" for msg in conversation])

# Define a summarization prompt
prompt_template = """Summarize the following conversation between the user and agent in a summary report format:

Conversation:
{conversation}

Summary:"""

# Set up the prompt with LangChain’s PromptTemplate
prompt = PromptTemplate(
    input_variables=["conversation"],
    template=prompt_template,
)

# Create the chain with the prompt and language model
summarization_chain = LLMChain(llm=llm, prompt=prompt)

# Generate the summary
summary = summarization_chain.run(conversation=conversation_text)

print("Summary of the conversation:")
print(
print(summary)
# Out:
# Summary of the conversation:
# The user asked the agent for feedback on their drawing. The agent suggested adding more blue to the ocean water and coloring the trees with different shades of green to make it stand out. The user agreed to make the suggested changes.
